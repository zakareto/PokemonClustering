# %% [markdown]
# <p align="center">
# <a href="https://github.com/zakareto"><img src = "https://upload.wikimedia.org/wikipedia/commons/thumb/5/53/Pok%C3%A9_Ball_icon.svg/640px-Pok%C3%A9_Ball_icon.svg.png" width = 100> </a>
# </p>
# <h1 align=center><font size = 5>Machine Learning para categorizar a los Pókemon.</font></h1>
# <br>

# %% [markdown]
# ## Librerías

# %%
import pandas as pd
from sklearn.cluster import KMeans

# %% [markdown]
# ## Obtención del set de datos

# %%
dataset = pd.read_csv('./In/PokemonDb.csv') #Ubicación del dataset
df = pd.DataFrame(dataset)   
df = df.drop(['Name', 'Variation', 'Type1', 'Type2'], axis=1 )

# %% [markdown]
# ## Ejecución Algoritmo K-Means

# %%
kmeans = KMeans(n_clusters=6, random_state=1).fit(df) #Usar n_clusters para el número de grupos deseados, random_state se define con cualquier número para asegurar los mismos resultados
print('='*64) #Estas líneas son para darle estética de impresión en la terminal
print('Total de grupos:', len(kmeans.cluster_centers_))
print('='*64)

#Predicción y obtención de resultados
dataset['grupo'] = kmeans.predict(df) #Nombre de la nueva columna donde pondremos nuestra predicción de algoritmo
dataset.to_csv('./Output/groups.csv', index=False, header=True) #Creación de archivo en carpeta destino

print('El Archivo "groups.csv" ha sido creado con éxito en la carpeta "out".')
# Out:
# ================================================================
# Total de grupos: 6
# ================================================================
# El Archivo "groups.csv" ha sido creado con éxito en la carpeta "out".

# %% [markdown]
# ## Imprimir grupos obtenidos

# %%
grouped_df = dataset.groupby(['grupo']) 
for key, group in grouped_df:  #Muestra cada grupo
    print(grouped_df.get_group(key), "\n\n", '='*180)
# Out:
#            Name              Variation     Type1     Type2  Total   HP  \
# 193      Mewtwo                    NaN   Psychic       NaN    680  106
# 194      Mewtwo                 Mega X   Psychic  Fighting    780  106
# 195      Mewtwo                 Mega Y   Psychic       NaN    780  106
# 301   Tyranitar                  Mega       Rock      Dark    700  100
# 302       Lugia                    NaN   Psychic    Flying    680  106
# 303       Ho-oh                    NaN      Fire    Flying    680  106
# 348     Slaking                    NaN    Normal       NaN    670  150
# 447   Salamence                  Mega     Dragon    Flying    700   95
# 451   Metagross                  Mega      Steel   Psychic    700   80
# 456      Latias                  Mega     Dragon   Psychic    700   80
# 458      Latios                  Mega     Dragon   Psychic    700   80
# 459      Kyogre                    NaN     Water       NaN    670  100
# 460      Kyogre                Primal      Water       NaN    770  100
# 461     Groudon                    NaN    Ground       NaN    670  100
# 462     Groudon                Primal     Ground      Fire    770  100
# 463    Rayquaza                    NaN    Dragon    Flying    680  105
# 464    Rayquaza                  Mega     Dragon    Flying    780  105
# 532    Garchomp                  Mega     Dragon    Ground    700  108
# 578      Dialga                    NaN     Steel    Dragon    680  100
# 579      Palkia                    NaN     Water    Dragon    680   90
# 581   Regigigas                    NaN    Normal       NaN    670  110
# 582    Giratina               Altered      Ghost    Dragon    680  150
# 583    Giratina                Origin      Ghost    Dragon    680  150
# 590      Arceus                    NaN    Normal       NaN    720  120
# 750    Reshiram                    NaN    Dragon      Fire    680  100
# 751      Zekrom                    NaN    Dragon  Electric    680  100
# 754      Kyurem                    NaN    Dragon       Ice    660  125
# 755      Kyurem                 Black     Dragon       Ice    700  125
# 756      Kyurem                 White     Dragon       Ice    700  125
# 837     Xerneas                    NaN     Fairy       NaN    680  126
# 838     Yveltal                    NaN      Dark    Flying    680  126
# 841    Zygarde                Complete    Dragon    Ground    708  216
# 843     Diancie                  Mega       Rock     Fairy    700   50
# 845       Hoopa               Unbound    Psychic      Dark    680   80
# 923    Solgaleo                    NaN   Psychic     Steel    680  137
# 924      Lunala                    NaN   Psychic     Ghost    680  137
# 933    Necrozma             Dusk Mane    Psychic     Steel    680   97
# 934    Necrozma            Dawn Wings    Psychic     Ghost    680   97
# 935    Necrozma                 Ultra    Psychic    Dragon    754   97
# 1026     Zacian         Crowned Sword      Fairy     Steel    720   92
# 1027     Zacian  Hero of Many Battles      Fairy       NaN    670   92
# 1028  Zamazenta        Crowned Shield   Fighting     Steel    720   92
# 1029  Zamazenta  Hero of Many Battles   Fighting       NaN    670   92
# 1030  Eternatus                    NaN    Poison    Dragon    690  140
# 1031  Eternatus             Eternamax     Poison    Dragon   1125  255
# 1041    Calyrex             Ice Rider    Psychic       Ice    680  100
# 1042    Calyrex          Shadow Rider    Psychic     Ghost    680  100
# 1061     Dialga                Origin      Steel    Dragon    680  100
# 1062     Palkia                Origin      Water    Dragon    680   90
#
#       Attack  Defense  Sp.Atk  Sp.Def  Speed  grupo
# 193      110       90     154      90    130      0
# 194      190      100     154     100    130      0
# 195      150       70     194     120    140      0
# 301      164      150      95     120     71      0
# 302       90      130      90     154    110      0
# 303      130       90     110     154     90      0
# 348      160      100      95      65    100      0
# 447      145      130     120      90    120      0
# 451      145      150     105     110    110      0
# 456      100      120     140     150    110      0
# 458      130      100     160     120    110      0
# 459      100       90     150     140     90      0
# 460      150       90     180     160     90      0
# 461      150      140     100      90     90      0
# 462      180      160     150      90     90      0
# 463      150       90     150      90     95      0
# 464      180      100     180     100    115      0
# 532      170      115     120      95     92      0
# 578      120      120     150     100     90      0
# 579      120      100     150     120    100      0
# 581      160      110      80     110    100      0
# 582      100      120     100     120     90      0
# 583      120      100     120     100     90      0
# 590      120      120     120     120    120      0
# 750      120      100     150     120     90      0
# 751      150      120     120     100     90      0
# 754      130       90     130      90     95      0
# 755      170      100     120      90     95      0
# 756      120       90     170     100     95      0
# 837      131       95     131      98     99      0
# 838      131       95     131      98     99      0
# 841      100      121      91      95     85      0
# 843      160      110     160     110    110      0
# 845      160       60     170     130     80      0
# 923      137      107     113      89     97      0
# 924      113       89     137     107     97      0
# 933      157      127     113     109     77      0
# 934      113      109     157     127     77      0
# 935      167       97     167      97    129      0
# 1026     170      115      80     115    148      0
# 1027     130      115      80     115    138      0
# 1028     130      145      80     145    128      0
# 1029     130      115      80     115    138      0
# 1030      85       95     145      95    130      0
# 1031     115      250     125     250    130      0
# 1041     165      150      85     130     50      0
# 1042      85       80     165     100    150      0
# 1061     100      120     150     120     90      0
# 1062     100      100     150     120    120      0
#
#  ====================================================================================================================================================================================
#             Name Variation     Type1   Type2  Total  HP  Attack  Defense  \
# 0      Bulbasaur       NaN     Grass  Poison    318  45      49       49
# 4     Charmander       NaN      Fire     NaN    309  39      52       43
# 9       Squirtle       NaN     Water     NaN    314  44      48       65
# 21     Pidgeotto       NaN    Normal  Flying    349  63      60       55
# 30         Ekans       NaN    Poison     NaN    288  35      60       44
# ...          ...       ...       ...     ...    ...  ..     ...      ...
# 996      Morgrem       NaN      Dark   Fairy    370  65      60       45
# 1016      Cufant       NaN     Steel     NaN    330  72      80       49
# 1047     Voltorb  Hisuian   Electric   Grass    330  40      30       50
# 1049       Zorua  Hisuian     Normal   Ghost    330  35      60       40
# 1051   Growlithe  Hisuian       Fire    Rock    350  60      75       45
#
#       Sp.Atk  Sp.Def  Speed  grupo
# 0         65      65     45      1
# 4         60      50     65      1
# 9         50      64     43      1
# 21        50      50     71      1
# 30        40      54     55      1
# ...      ...     ...    ...    ...
# 996       75      55     70      1
# 1016      40      49     40      1
# 1047      55      55    100      1
# 1049      85      40     70      1
# 1051      65      50     55      1
#
# [239 rows x 12 columns]
#
#  ====================================================================================================================================================================================
#              Name Variation   Type1    Type2  Total   HP  Attack  Defense  \
# 2        Venusaur       NaN   Grass   Poison    525   80      82       83
# 6       Charizard       NaN    Fire   Flying    534   78      84       78
# 11      Blastoise       NaN   Water      NaN    530   79      83      100
# 19       Beedrill      Mega     Bug   Poison    495   65     150       40
# 22        Pidgeot       NaN  Normal   Flying    479   83      80       75
# ...           ...       ...     ...      ...    ...  ...     ...      ...
# 1065      Wyrdeer       NaN  Normal  Psychic    525  103     105       72
# 1067  Basculegion     Male    Water    Ghost    530  120     112       65
# 1068  Basculegion   Female    Water    Ghost    530  120      92       65
# 1069      Kleavor       NaN     Bug     Rock    505   70     135       95
# 1070     Ursaluna       NaN  Normal   Ground    550  130     140      105
#
#       Sp.Atk  Sp.Def  Speed  grupo
# 2        100     100     80      2
# 6        109      85    100      2
# 11        85     105     78      2
# 19        15      80    145      2
# 22        70      70    101      2
# ...      ...     ...    ...    ...
# 1065     105      75     65      2
# 1067      80      75     78      2
# 1068     100      75     78      2
# 1069      45      75     85      2
# 1070      45      80     50      2
#
# [352 rows x 12 columns]
#
#  ====================================================================================================================================================================================
#             Name       Variation     Type1     Type2  Total  HP  Attack  \
# 1        Ivysaur             NaN     Grass    Poison    405  60      62
# 5     Charmeleon             NaN      Fire       NaN    405  58      64
# 10     Wartortle             NaN     Water       NaN    405  59      63
# 15    Butterfree             NaN       Bug    Flying    395  60      45
# 18      Beedrill             NaN       Bug    Poison    395  65      90
# ...          ...             ...       ...       ...    ...  ..     ...
# 1032       Kubfu             NaN  Fighting       NaN    385  60      90
# 1043     Sneasel        Hisuian     Poison  Fighting    430  55      95
# 1045    Qwilfish        Hisuian       Dark    Poison    440  65      95
# 1054     Sliggoo        Hisuian     Dragon     Steel    452  58      75
# 1066    Basculin  White-Striped      Water       NaN    460  70      92
#
#       Defense  Sp.Atk  Sp.Def  Speed  grupo
# 1          63      80      80     60      3
# 5          58      80      65     80      3
# 10         80      65      80     58      3
# 15         50      90      80     70      3
# 18         40      45      80     75      3
# ...       ...     ...     ...    ...    ...
# 1032       60      53      50     72      3
# 1043       55      35      75    115      3
# 1045       85      55      55     85      3
# 1054       83      83     113     40      3
# 1066       65      80      55     98      3
#
# [201 rows x 12 columns]
#
#  ====================================================================================================================================================================================
#           Name Variation    Type1   Type2  Total  HP  Attack  Defense  Sp.Atk  \
# 13    Caterpie       NaN      Bug     NaN    195  45      30       35      20
# 14     Metapod       NaN      Bug     NaN    205  50      20       55      25
# 16      Weedle       NaN      Bug  Poison    195  40      35       30      20
# 17      Kakuna       NaN      Bug  Poison    205  45      25       50      25
# 20      Pidgey       NaN   Normal  Flying    251  40      45       40      35
# ...        ...       ...      ...     ...    ...  ..     ...      ...     ...
# 992    Hatenna       NaN  Psychic     NaN    265  42      30       45      56
# 995   Impidimp       NaN     Dark   Fairy    265  45      45       30      55
# 1004   Milcery       NaN    Fairy     NaN    270  45      40       40      50
# 1008      Snom       NaN      Ice     Bug    185  30      25       35      45
# 1023    Dreepy       NaN   Dragon   Ghost    270  28      60       30      40
#
#       Sp.Def  Speed  grupo
# 13        20     45      4
# 14        25     30      4
# 16        20     50      4
# 17        25     35      4
# 20        35     56      4
# ...      ...    ...    ...
# 992       53     39      4
# 995       40     50      4
# 1004      61     34      4
# 1008      30     20      4
# 1023      30     82      4
#
# [103 rows x 12 columns]
#
#  ====================================================================================================================================================================================
#            Name   Variation   Type1   Type2  Total   HP  Attack  Defense  \
# 3      Venusaur       Mega    Grass  Poison    625   80     100      123
# 7     Charizard      Mega X    Fire  Dragon    634   78     130      111
# 8     Charizard      Mega Y    Fire  Flying    634   78     104       78
# 12    Blastoise        Mega   Water     NaN    630   79     103      120
# 23      Pidgeot       Mega   Normal  Flying    579   83      80       80
# ...         ...         ...     ...     ...    ...  ...     ...      ...
# 1039  Spectrier         NaN   Ghost     NaN    580  100      65       60
# 1052   Arcanine    Hisuian     Fire    Rock    555   95     115       80
# 1055     Goodra    Hisuian   Dragon   Steel    600   80     100      100
# 1063   Enamorus  Incarnate    Fairy  Flying    580   74     115       70
# 1064   Enamorus   Therian     Fairy  Flying    580   74     115      110
#
#       Sp.Atk  Sp.Def  Speed  grupo
# 3        122     120     80      5
# 7        130      85    100      5
# 8        159     115    100      5
# 12       135     115     78      5
# 23       135      80    121      5
# ...      ...     ...    ...    ...
# 1039     145      80    130      5
# 1052      95      80     90      5
# 1055     110     150     60      5
# 1063     135      80    106      5
# 1064     135     100     46      5
#
# [127 rows x 12 columns]
#
#  ====================================================================================================================================================================================
